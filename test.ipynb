# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot([1,5,4,8,9],label='data')
plt.plot([5,4,7,8,9],label='yazan')
plt.title('test')
plt.xlabel('index')
plt.ylabel('the actual data')
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.figure()
plt.plot([1,5,4,8,9],label='data')
plt.plot([5,4,7,8,9],label='yazan')
plt.title('test')
plt.xlabel('index')
plt.ylabel('the actual data')
plt.legend()
plt.show()

# %%
flights=sns.load_dataset('flights')

# %%
flights.head(10)
# Out:
#    year      month  passengers
# 0  1949    January         112
# 1  1949   February         118
# 2  1949      March         132
# 3  1949      April         129
# 4  1949        May         121
# 5  1949       June         135
# 6  1949       July         148
# 7  1949     August         148
# 8  1949  September         136
# 9  1949    October         119

# %%
sns.relplot(x='year',y='passengers',data=flights)

# %%
year_sums=flights.groupby('year',as_index=False).sum()
year_mean=flights.groupby('year',as_index=False).mean()

# %%
year_sums
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.relplot(x='year',y='passengers',data=year_sums)

# %%
year_mean
# Out:
#     year  passengers
# 0   1949  126.666667
# 1   1950  139.666667
# 2   1951  170.166667
# 3   1952  197.000000
# 4   1953  225.000000
# 5   1954  238.916667
# 6   1955  284.000000
# 7   1956  328.250000
# 8   1957  368.416667
# 9   1958  381.000000
# 10  1959  428.333333
# 11  1960  476.166667

# %%
sns.relplot(x='year',y='passengers',data=year_mean)

# %%
sns.lmplot(x='year',y='passengers',data=year_sums)

# %%
graph=sns.barplot(x='year',y='passengers',data=flights)

# %%
exercise
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-5f9bd819df14> in <module>
# ----> 1 exercise
#
# NameError: name 'exercise' is not defined
